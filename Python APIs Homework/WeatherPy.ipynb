# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# '68829678e4f18d0cf08f6a9304d83e03'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ## Generate Cities List

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=minab
# Processing Record 2 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=avarua
# Processing Record 3 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ilulissat
# Processing Record 4 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kodiak
# Processing Record 5 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=coquimbo
# Processing Record 6 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=busselton
# Processing Record 7 | Kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kapit
# Processing Record 8 | Catanzaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=catanzaro
# Processing Record 9 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20patricio
# Processing Record 10 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dikson
# Processing Record 11 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=albany
# Processing Record 12 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=victoria
# Processing Record 13 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=airai
# Processing Record 14 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tiksi
# Processing Record 15 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mahebourg
# Processing Record 16 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vestmannaeyjar
# Processing Record 17 | Abonnema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=abonnema
# Processing Record 18 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=atuona
# Processing Record 19 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=east%20london
# Processing Record 20 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ushuaia
# Processing Record 21 | Allapalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=allapalli
# Processing Record 22 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dingle
# Processing Record 23 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=carnarvon
# Processing Record 24 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=butaritari
# Processing Record 25 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=barrow
# Processing Record 26 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=guerrero%20negro
# Processing Record 27 | Chadiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chadiza
# Processing Record 28 | Palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=palauig
# Processing Record 29 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=iqaluit
# Processing Record 30 | Ust-Barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ust-barguzin
# Processing Record 31 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hithadhoo
# Processing Record 32 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vanimo
# Processing Record 33 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zhigansk
# Processing Record 34 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 35 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=flinders
# Processing Record 36 | Devils Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=devils%20lake
# Processing Record 37 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sorland
# Processing Record 38 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mataura
# Processing Record 39 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nikolskoye
# Processing Record 40 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chokurdakh
# Processing Record 41 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hermanus
# Processing Record 42 | Tacuati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tacuati
# Processing Record 43 | Bjornevatn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bjornevatn
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=inuvik
# Processing Record 45 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mayor%20pablo%20lagerenza
# Processing Record 46 | Maroantsetra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=maroantsetra
# Processing Record 47 | Punta Alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=punta%20alta
# Processing Record 48 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=rikitea
# Processing Record 49 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=caravelas
# Processing Record 50 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cape%20town
# Processing Record 51 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mezen
# Processing Record 52 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=axim
# Processing Record 53 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pisco
# Processing Record 54 | Mandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mandan
# Processing Record 55 | Grand-Santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=grand-santi
# Processing Record 56 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=faanui
# Processing Record 57 | Shagonar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=shagonar
# Processing Record 58 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=provideniya
# Processing Record 59 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pacific%20grove
# Processing Record 60 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yerbogachen
# Processing Record 61 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=walvis%20bay
# Processing Record 62 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=soyo
# Processing Record 63 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vaini
# Processing Record 64 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kapaa
# Processing Record 65 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20alfred
# Processing Record 66 | Thanh Hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=thanh%20hoa
# Processing Record 67 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=meulaboh
# Processing Record 68 | Dorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dorado
# Processing Record 69 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=moose%20factory
# Processing Record 70 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bambous%20virieux
# City not found. Skipping...
# Processing Record 71 | Montrose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=montrose
# Processing Record 72 | Cambuci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cambuci
# Processing Record 73 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=salalah
# Processing Record 74 | Kuopio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kuopio
# City not found. Skipping...
# Processing Record 75 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mount%20gambier
# Processing Record 76 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tuatapere
# Processing Record 77 | Shiyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=shiyan
# Processing Record 78 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20cristobal
# Processing Record 79 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=punta%20arenas
# Processing Record 80 | Effingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=effingham
# Processing Record 81 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bluff
# Processing Record 82 | Gardez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=gardez
# Processing Record 83 | Yantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yantal
# Processing Record 84 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=upernavik
# City not found. Skipping...
# Processing Record 85 | Zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zapolyarnyy
# Processing Record 86 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mar%20del%20plata
# Processing Record 87 | Tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tanout
# Processing Record 88 | Benjamin Constant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=benjamin%20constant
# Processing Record 89 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ambilobe
# Processing Record 90 | Birobidzhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=birobidzhan
# Processing Record 91 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=arraial%20do%20cabo
# Processing Record 92 | Kirkwall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kirkwall
# Processing Record 93 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vardo
# Processing Record 94 | Villa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=villa%20maria
# Processing Record 95 | Urucui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=urucui
# Processing Record 96 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=komsomolskiy
# Processing Record 97 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saskylakh
# Processing Record 98 | Molina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=molina
# Processing Record 99 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=itoman
# Processing Record 100 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sibolga
# Processing Record 101 | Lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lahaina
# Processing Record 102 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=qaanaaq
# Processing Record 103 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pangnirtung
# Processing Record 104 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=clyde%20river
# Processing Record 105 | Peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=peleduy
# City not found. Skipping...
# Processing Record 106 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=haines%20junction
# Processing Record 107 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=husavik
# Processing Record 108 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=muros
# Processing Record 109 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20hedland
# Processing Record 110 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=khatanga
# City not found. Skipping...
# Processing Record 111 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=severo-kurilsk
# Processing Record 112 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=thompson
# Processing Record 113 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=faya
# Processing Record 114 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saint-philippe
# Processing Record 115 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hilo
# Processing Record 116 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zhangye
# Processing Record 117 | Mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mildura
# Processing Record 118 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=baykit
# Processing Record 119 | Sao Miguel do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sao%20miguel%20do%20araguaia
# Processing Record 120 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sitka
# Processing Record 121 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bundaberg
# Processing Record 122 | Simbahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=simbahan
# City not found. Skipping...
# Processing Record 123 | Humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=humaita
# Processing Record 124 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ribeira%20grande
# Processing Record 125 | Waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=waddan
# Processing Record 126 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=arman
# City not found. Skipping...
# Processing Record 127 | Bhag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bhag
# Processing Record 128 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=puerto%20ayora
# Processing Record 129 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=eyl
# City not found. Skipping...
# Processing Record 130 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pevek
# Processing Record 131 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=carutapera
# Processing Record 132 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tasiilaq
# Processing Record 133 | Newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=newport
# City not found. Skipping...
# Processing Record 134 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=brae
# Processing Record 135 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=taoudenni
# Processing Record 136 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=takoradi
# Processing Record 137 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=jamestown
# Processing Record 138 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saint%20george
# Processing Record 139 | Kolokani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kolokani
# Processing Record 140 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=new%20norfolk
# Processing Record 141 | Kuybysheve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kuybysheve
# Processing Record 142 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yar-sale
# Processing Record 143 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=norman%20wells
# Processing Record 144 | Zyryanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zyryanovsk
# Processing Record 145 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=laguna
# Processing Record 146 | Tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tagusao
# Processing Record 147 | Pakxan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pakxan
# Processing Record 148 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hobart
# Processing Record 149 | Tres Palos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tres%20palos
# Processing Record 150 | Port Keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20keats
# Processing Record 151 | Lluta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lluta
# City not found. Skipping...
# Processing Record 152 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=shingu
# Processing Record 153 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20lincoln
# Processing Record 154 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=araouane
# Processing Record 155 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=north%20bend
# Processing Record 156 | Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=puerto%20carreno
# City not found. Skipping...
# Processing Record 157 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=rocha
# Processing Record 158 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=thunder%20bay
# City not found. Skipping...
# Processing Record 159 | Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ulaanbaatar
# Processing Record 160 | Surinam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=surinam
# Processing Record 161 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tautira
# Processing Record 162 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lebu
# Processing Record 163 | Lahat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lahat
# Processing Record 164 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=solnechnyy
# Processing Record 165 | Bismarck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bismarck
# Processing Record 166 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=leshukonskoye
# Processing Record 167 | Sanmenxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sanmenxia
# Processing Record 168 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mareeba
# Processing Record 169 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bethel
# Processing Record 170 | Tucurui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tucurui
# City not found. Skipping...
# Processing Record 171 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sao%20filipe
# Processing Record 172 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=puerto%20leguizamo
# Processing Record 173 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tucuman
# Processing Record 174 | Kano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kano
# Processing Record 175 | Simpang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=simpang
# Processing Record 176 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port-cartier
# Processing Record 177 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=longyearbyen
# Processing Record 178 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=poum
# Processing Record 179 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=berlevag
# Processing Record 180 | Soe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=soe
# City not found. Skipping...
# Processing Record 181 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=castro
# Processing Record 182 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=isangel
# Processing Record 183 | Fort Walton Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=fort%20walton%20beach
# Processing Record 184 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ketchikan
# Processing Record 185 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kamenka
# Processing Record 186 | Anantapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=anantapur
# Processing Record 187 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=prince%20rupert
# Processing Record 188 | Oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=oriximina
# City not found. Skipping...
# Processing Record 189 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=katsuura
# Processing Record 190 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lompoc
# Processing Record 191 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hambantota
# Processing Record 192 | Tay Ninh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tay%20ninh
# Processing Record 193 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ginir
# Processing Record 194 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20elizabeth
# Processing Record 195 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=batagay
# Processing Record 196 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=narsaq
# Processing Record 197 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20quintin
# City not found. Skipping...
# Processing Record 198 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=roald
# Processing Record 199 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nuuk
# Processing Record 200 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=paita
# Processing Record 201 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saint%20anthony
# Processing Record 202 | Russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=russell
# Processing Record 203 | Garmsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=garmsar
# Processing Record 204 | Chon Daen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chon%20daen
# Processing Record 205 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ponta%20delgada
# Processing Record 206 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=raudeberg
# Processing Record 207 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=luderitz
# Processing Record 208 | Santa Cruz del Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=santa%20cruz%20del%20sur
# Processing Record 209 | Sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sungaipenuh
# Processing Record 210 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=georgetown
# Processing Record 211 | Parsabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=parsabad
# Processing Record 212 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yulara
# Processing Record 213 | Vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vytegra
# Processing Record 214 | Shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=shubarshi
# Processing Record 215 | Bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bayir
# Processing Record 216 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=karratha
# Processing Record 217 | Normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=normandin
# Processing Record 218 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=waingapu
# Processing Record 219 | Karwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=karwar
# Processing Record 220 | Morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=morondava
# City not found. Skipping...
# Processing Record 221 | Babu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=babu
# Processing Record 222 | Soto la Marina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=soto%20la%20marina
# Processing Record 223 | Sangueya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sangueya
# Processing Record 224 | Macaubas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=macaubas
# Processing Record 225 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tiznit
# Processing Record 226 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=maceio
# Processing Record 227 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=arlit
# Processing Record 228 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chuy
# Processing Record 229 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=fare
# Processing Record 230 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=aykhal
# Processing Record 231 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kahului
# City not found. Skipping...
# Processing Record 232 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=poya
# Processing Record 233 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=constitucion
# Processing Record 234 | Cumberland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cumberland
# Processing Record 235 | Sai Buri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sai%20buri
# Processing Record 236 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=college
# Processing Record 237 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vila%20velha
# Processing Record 238 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vao
# City not found. Skipping...
# Processing Record 239 | Betanzos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=betanzos
# Processing Record 240 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kaitangata
# Processing Record 241 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=praia%20da%20vitoria
# Processing Record 242 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=itarema
# Processing Record 243 | Osoyoos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=osoyoos
# City not found. Skipping...
# Processing Record 244 | Khromtau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=khromtau
# Processing Record 245 | Yacuiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yacuiba
# Processing Record 246 | San Buenaventura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20buenaventura
# Processing Record 247 | Mwingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mwingi
# Processing Record 248 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=gamba
# Processing Record 249 | Campoverde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=campoverde
# Processing Record 250 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cherskiy
# Processing Record 251 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dunedin
# Processing Record 252 | Kibakwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kibakwe
# Processing Record 253 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=fortuna
# Processing Record 254 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nishihara
# City not found. Skipping...
# Processing Record 255 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vostok
# Processing Record 256 | Northview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=northview
# Processing Record 257 | Puerto Narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=puerto%20narino
# City not found. Skipping...
# Processing Record 258 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kirakira
# Processing Record 259 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=los%20llanos%20de%20aridane
# Processing Record 260 | Nikolayevsk-na-amure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nikolayevsk-na-amure
# City not found. Skipping...
# Processing Record 261 | Lieksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lieksa
# Processing Record 262 | Plainview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=plainview
# Processing Record 263 | Zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zeya
# Processing Record 264 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lorengau
# Processing Record 265 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hami
# Processing Record 266 | Damietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=damietta
# Processing Record 267 | Herzberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=herzberg
# Processing Record 268 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=namibe
# Processing Record 269 | Koulamoutou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=koulamoutou
# Processing Record 270 | Sidi Ali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sidi%20ali
# Processing Record 271 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=necochea
# Processing Record 272 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=fairbanks
# Processing Record 273 | Katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=katherine
# Processing Record 274 | Murdochville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=murdochville
# Processing Record 275 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kavieng
# Processing Record 276 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cidreira
# Processing Record 277 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=turukhansk
# Processing Record 278 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saint-francois
# Processing Record 279 | Khvoynaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=khvoynaya
# Processing Record 280 | Camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=camopi
# Processing Record 281 | Cuorgne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cuorgne
# Processing Record 282 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=acapulco
# City not found. Skipping...
# Processing Record 283 | Cheyenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cheyenne
# Processing Record 284 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ampanihy
# Processing Record 285 | Belton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=belton
# Processing Record 286 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=torbay
# Processing Record 287 | Cordoba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cordoba
# Processing Record 288 | Lusaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lusaka
# Processing Record 289 | Basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=basco
# City not found. Skipping...
# Processing Record 290 | Klasterec nad Ohri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=klasterec%20nad%20ohri
# Processing Record 291 | Chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chifeng
# Processing Record 292 | Chudovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chudovo
# Processing Record 293 | Lejanias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lejanias
# Processing Record 294 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=antofagasta
# Processing Record 295 | Naberera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=naberera
# Processing Record 296 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hobyo
# City not found. Skipping...
# Processing Record 297 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=roebourne
# Processing Record 298 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=fukue
# Processing Record 299 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=te%20anau
# Processing Record 300 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=burnie
# Processing Record 301 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bilma
# Processing Record 302 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=palmer
# City not found. Skipping...
# Processing Record 303 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=luanda
# Processing Record 304 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=samarai
# Processing Record 305 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=imbituba
# Processing Record 306 | Sri Aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sri%20aman
# Processing Record 307 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=khandyga
# City not found. Skipping...
# Processing Record 308 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mehamn
# Processing Record 309 | Trollhattan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=trollhattan
# Processing Record 310 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nyurba
# Processing Record 311 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=port%20hardy
# Processing Record 312 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lagoa
# Processing Record 313 | Wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=wasilla
# Processing Record 314 | Kasungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kasungu
# Processing Record 315 | Goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=goure
# City not found. Skipping...
# Processing Record 316 | Dillon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dillon
# Processing Record 317 | Mizusawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mizusawa
# Processing Record 318 | Itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=itaituba
# Processing Record 319 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yellowknife
# Processing Record 320 | Blythe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=blythe
# Processing Record 321 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=saint-joseph
# City not found. Skipping...
# Processing Record 322 | Mbanza-Ngungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mbanza-ngungu
# Processing Record 323 | Grindavik
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20carlos%20de%20bariloche
# Processing Record 471 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=buchanan
# Processing Record 472 | Carbondale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=carbondale
# Processing Record 473 | Vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=vallenar
# Processing Record 474 | Seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=seydi
# Processing Record 475 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=havre-saint-pierre
# Processing Record 476 | Horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=horsham
# Processing Record 477 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=namatanai
# Processing Record 478 | Anjangaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=anjangaon
# Processing Record 479 | San Ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20ignacio
# City not found. Skipping...
# Processing Record 480 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pochutla
# Processing Record 481 | Honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=honningsvag
# Processing Record 482 | Siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=siocon
# Processing Record 483 | Igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=igrim
# Processing Record 484 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hervey%20bay
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 485 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=marawi
# Processing Record 486 | Perpignan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=perpignan
# Processing Record 487 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hualmay
# Processing Record 488 | Ciudad Valles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ciudad%20valles
# Processing Record 489 | Makanya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=makanya
# Processing Record 490 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kavaratti
# City not found. Skipping...
# Processing Record 491 | Susangerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=susangerd
# Processing Record 492 | Kampene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kampene
# Processing Record 493 | Grinnell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=grinnell
# Processing Record 494 | Luxor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=luxor
# Processing Record 495 | Impfondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=impfondo
# Processing Record 496 | Hede
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hede
# Processing Record 497 | Haikou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=haikou
# Processing Record 498 | De-Kastri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=de-kastri
# Processing Record 499 | Kyren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kyren
# Processing Record 500 | Barra de Sao Francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=barra%20de%20sao%20francisco
# Processing Record 501 | Kasempa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kasempa
# Processing Record 502 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=buraydah
# Processing Record 503 | Methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=methoni
# Processing Record 504 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=flin%20flon
# Processing Record 505 | Hope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hope
# Processing Record 506 | Muana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=muana
# Processing Record 507 | Jiexiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=jiexiu
# Processing Record 508 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=yatou
# Processing Record 509 | Cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cooma
# Processing Record 510 | Visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=visby
# Processing Record 511 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=teya
# Processing Record 512 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=bandarbeyla
# Processing Record 513 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=porto%20novo
# Processing Record 514 | Colombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=colombo
# Processing Record 515 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hamilton
# Processing Record 516 | Dunmore East
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=dunmore%20east
# Processing Record 517 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sisimiut
# Processing Record 518 | Indi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=indi
# Processing Record 519 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=beyneu
# Processing Record 520 | Pak Chong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pak%20chong
# Processing Record 521 | Mont-de-Marsan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mont-de-marsan
# Processing Record 522 | Kabalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kabalo
# Processing Record 523 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=zhangjiakou
# City not found. Skipping...
# Processing Record 524 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=adrar
# Processing Record 525 | Florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=florianopolis
# Processing Record 526 | Tank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tank
# Processing Record 527 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=padang
# Processing Record 528 | Sonoita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sonoita
# Processing Record 529 | Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=biltine
# Processing Record 530 | Puttur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=puttur
# Processing Record 531 | Paso de Carrasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=paso%20de%20carrasco
# City not found. Skipping...
# Processing Record 532 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=beloha
# Processing Record 533 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=sola
# Processing Record 534 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=shelburne
# Processing Record 535 | Pinjaur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pinjaur
# Processing Record 536 | Tarrafal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=tarrafal
# Processing Record 537 | Scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=scottsbluff
# Processing Record 538 | Channel-Port aux Basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=channel-port%20aux%20basques
# Processing Record 539 | Cadillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cadillac
# Processing Record 540 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=colares
# Processing Record 541 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=abu%20dhabi
# Processing Record 542 | Nyuksenitsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=nyuksenitsa
# Processing Record 543 | Chodavaram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=chodavaram
# Processing Record 544 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kodinsk
# Processing Record 545 | Wapakoneta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=wapakoneta
# Processing Record 546 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lazaro%20cardenas
# Processing Record 547 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=la%20ronge
# Processing Record 548 | Pativilca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pativilca
# Processing Record 549 | Khao Wong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=khao%20wong
# Processing Record 550 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=talara
# Processing Record 551 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=opuwo
# Processing Record 552 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=manokwari
# Processing Record 553 | Mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mangrol
# Processing Record 554 | Novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=novikovo
# Processing Record 555 | Phrae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=phrae
# Processing Record 556 | Mgachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mgachi
# Processing Record 557 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cabo%20san%20lucas
# Processing Record 558 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=xining
# Processing Record 559 | Manjacaze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=manjacaze
# City not found. Skipping...
# Processing Record 560 | Turtas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=turtas
# Processing Record 561 | Karaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=karaton
# Processing Record 562 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=cockburn%20town
# Processing Record 563 | Berezovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=berezovyy
# Processing Record 564 | Loudon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=loudon
# Processing Record 565 | Langa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=langa
# Processing Record 566 | Panhala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=panhala
# Processing Record 567 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=san%20policarpo
# Processing Record 568 | Krasnopavlivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=krasnopavlivka
# Processing Record 569 | Businga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=businga
# Processing Record 570 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=hofn
# Processing Record 571 | Lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=lakatoro
# Processing Record 572 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=pangody
# Processing Record 573 | Mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=mujiayingzi
# Processing Record 574 | Kostomuksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=kostomuksha
# Processing Record 575 | Gorin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=gorin
# Processing Record 576 | Rorvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=rorvik
# Processing Record 577 | Ponyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68829678e4f18d0cf08f6a9304d83e03&q=ponyri

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max Temp      577
# Wind Speed    577
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('Output_CSV/weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-235e0170cad0> in <module>
#       1 # Save data frame to CSV
# ----> 2 weather_data.to_csv('Output_CSV/weather_data.csv')
#       3
#       4 # Display data frame head
#       5 weather_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output_CSV/weather_data.csv'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
